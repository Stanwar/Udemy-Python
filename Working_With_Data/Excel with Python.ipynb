# %%
import pandas as pd

# %%
xlsfile = pd.ExcelFile('sample_excel.xlsx')

# %%
dFrame = xlsfile.parse('VISUALIZATION')

# %%
dFrame
# Out:
#                 Unnamed: 0                                         Unnamed: 1  \
# 0               RISK LEVEL                                          RISK TIER
# 1                      LOW                                                583
# 2                   MEDIUM                                                604
# 3                     HIGH                                                106
# 4                      NaN                                                NaN
# 5                      NaN                                                NaN
# 6                      NaN                                                NaN
# 7                      NaN                                                NaN
# 8   RISK LEVEL DEFINITIONS                                                NaN
# 9                      NaN                                                NaN
# 10               UCSD RISK                                                NaN
# ...
